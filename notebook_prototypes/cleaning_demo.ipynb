# %%
#Read dataframes
import pandas as pd
df_airlines = pd.read_csv('../flight_data/airlines.csv')
df_airplanes = pd.read_csv('../flight_data/airplanes.csv', on_bad_lines='skip')
df_airports = pd.read_csv('../flight_data/airports.csv', on_bad_lines='skip')
df_routes =  pd.read_csv('../flight_data/routes.csv', on_bad_lines='skip')

# %%
#Airlines
df_airlines_cleaned = df_airlines.drop(df_airlines.columns[0], axis=1) \
                                 .drop(['Alias', 'Callsign', 'Active'], axis=1)

# %%
#Airports
df_airports_cleaned = df_airports.drop(df_airports.columns[0], axis=1) \
                                 .drop(['Timezone','Altitude', 'DST', 'Tz database time zone', 'Type', 'Source'], axis=1)

# %%
df_airports_cleaned.head()
# Out:
#    Airport ID                                         Name          City  \
# 0           1                               Goroka Airport        Goroka
# 1           2                               Madang Airport        Madang
# 2           3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3           4                               Nadzab Airport        Nadzab
# 4           5  Port Moresby Jacksons International Airport  Port Moresby
#
#             Country IATA  ICAO  Latitude   Longitude
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001

# %%
#Routes
df_routes_cleaned = df_routes.drop(df_routes.columns[0], axis=1) \
                                 .drop(['Codeshare','Stops', 'Airline'], axis=1) 

#Remember = source and destination airport equals IATA number
df_routes_cleaned.describe()
# Out:
#        Airline ID Source airport Source airport ID Destination airport  \
# count       67663          67663             67663               67663
# unique        548           3409              3321                3418
# top          4296            ATL              3682                 ATL
# freq         2484            915               915                 911
#
#        Destination airport ID Equipment
# count                   67663     67645
# unique                   3327      3945
# top                      3682       320
# freq                      911      9180

# %%
df_airplanes_cleaned = df_routes.drop(df_airplanes.columns[0], axis=1) 

df_airplanes_cleaned
# Out:
#       Airline Airline ID Source airport Source airport ID Destination airport  \
# 0          2B        410            AER              2965                 KZN
# 1          2B        410            ASF              2966                 KZN
# 2          2B        410            ASF              2966                 MRV
# 3          2B        410            CEK              2968                 KZN
# 4          2B        410            CEK              2968                 OVB
# ...       ...        ...            ...               ...                 ...
# 67658      ZL       4178            WYA              6334                 ADL
# 67659      ZM      19016            DME              4029                 FRU
# 67660      ZM      19016            FRU              2912                 DME
# 67661      ZM      19016            FRU              2912                 OSS
# 67662      ZM      19016            OSS              2913                 FRU
#
#       Destination airport ID Codeshare  Stops Equipment
# 0                       2990       NaN      0       CR2
# 1                       2990       NaN      0       CR2
# 2                       2962       NaN      0       CR2
# 3                       2990       NaN      0       CR2
# 4                       4078       NaN      0       CR2
# ...                      ...       ...    ...       ...
# 67658                   3341       NaN      0       SF3
# 67659                   2912       NaN      0       734
# 67660                   4029       NaN      0       734
# 67661                   2913       NaN      0       734
# 67662                   2912       NaN      0       734
#
# [67663 rows x 9 columns]
